# %%
import scipy
import numpy as np
import pandas
import matplotlib.pyplot as plt
import plotly as ply

# %%
v = np.exp(1)

# %%
alpha = 1
t = 1

# %%
def cal(alpha, t):
    ans1 = (alpha/(4*np.sqrt(2))) * (((np.exp((-3+2*np.sqrt(2))*t))) - (np.exp((-3-2*np.sqrt(2))*t)))
    ans2 = (alpha*np.exp(-t)/2) + (alpha/(4*np.sqrt(2))) * (((1-np.sqrt(2))*(np.exp((-3+2*np.sqrt(2))*t))) - ((1+np.sqrt(2))*np.exp((-3-2*np.sqrt(2))*t)))
    ans3 = np.exp(-t)
    ans = ans1 + ans2 + ans3
    return ans

# %%
ans1 = alpha/(4*np.sqrt(2)) * (np.exp(-3+2*np.sqrt(2))*t) - (np.exp(-3-2*np.sqrt(2))*t)

# %%
ans1
# Out:
# 0.1459631817030955

# %%
ans2 = (alpha*np.exp(-t)/2) + alpha/(4*np.sqrt(2)) * (((1-np.sqrt(2))*(np.exp(-3+2*np.sqrt(2))*t)) - ((1+np.sqrt(2))*np.exp(-3-2*np.sqrt(2))*t))

# %%
ans3 = np.exp(-t)

# %%
ans = ans1 + ans2 + ans3

# %%
v = cal(1,0)
print (v)
# Out:
# 1.0

# %%
alpha = 1
final = []
for t in np.linspace(0,1,1000):
    final.append(cal(alpha,t))
print (final)
# Out:
# [1.0, 1.0019925026702083, 1.003966085232025, 1.0059208649985585, 1.0078569585932367, 1.009774481953824, 1.0116735503364194, 1.0135542783194276, 1.015416779807509, 1.017261168035508, 1.0190875555723524, 1.0208960543249395, 1.0226867755419908, 1.0244598298178897, 1.0262153270964953, 1.0279533766749325, 1.0296740872073624, 1.0313775667087297, 1.033063922558488, 1.0347332615043043, 1.0363856896657406, 1.0380213125379159, 1.0396402349951441, 1.0412425612945557, 1.0428283950796915, 1.0443978393840818, 1.0459509966348006, 1.0474879686560017, 1.049008856672432, 1.0505137613129267, 1.052002782613882, 1.053476020022709, 1.0549335724012663, 1.0563755380292748, 1.0578020146077096, 1.0592130992621753, 1.0606088885462583, 1.0619894784448636, 1.0633549643775273, 1.0647054412017154, 1.0660410032160978, 1.0673617441638088, 1.0686677572356824, 1.0699591350734754, 1.0712359697730665, 1.0724983528876393, 1.0737463754308463, 1.0749801278799545, 1.0761997001789732, 1.077405181741761, 1.0785966614551197, 1
# ...

# %%
plt.plot(final)

# %%
np.linspace(0,1,1000)
# Out:
# array([0.        , 0.001001  , 0.002002  , 0.003003  , 0.004004  ,
#        0.00500501, 0.00600601, 0.00700701, 0.00800801, 0.00900901,
#        0.01001001, 0.01101101, 0.01201201, 0.01301301, 0.01401401,
#        0.01501502, 0.01601602, 0.01701702, 0.01801802, 0.01901902,
#        0.02002002, 0.02102102, 0.02202202, 0.02302302, 0.02402402,
#        0.02502503, 0.02602603, 0.02702703, 0.02802803, 0.02902903,
#        0.03003003, 0.03103103, 0.03203203, 0.03303303, 0.03403403,
#        0.03503504, 0.03603604, 0.03703704, 0.03803804, 0.03903904,
#        0.04004004, 0.04104104, 0.04204204, 0.04304304, 0.04404404,
#        0.04504505, 0.04604605, 0.04704705, 0.04804805, 0.04904905,
#        0.05005005, 0.05105105, 0.05205205, 0.05305305, 0.05405405,
#        0.05505506, 0.05605606, 0.05705706, 0.05805806, 0.05905906,
#        0.06006006, 0.06106106, 0.06206206, 0.06306306, 0.06406406,
#        0.06506507, 0.06606607, 0.06706707, 0.06806807, 0.06906907,
# ...
